# %% [markdown]
# # 通用行情数据接口

# %%
import tushare as ts
ts.set_token('{your_token}')#账号的token
df = ts.pro_bar()

# %% [markdown]
# # 爬取20年内的基金数据

# %% [markdown]
# ### 生成日期列表

# %%
import datetime
import time
today = '2020-12-15'
date_list = []
time_tuple = time.strptime(today,"%Y-%m-%d")
year,month,day = time_tuple[:3]
for i in range(365*20):
    date_list.append((datetime.date(year,month,day)-datetime.timedelta(days=i)).strftime("%Y%m%d"))
date_list[0:5]
# Out:
# ['20201215', '20201214', '20201213', '20201212', '20201211']

# %% [markdown]
# ### 爬取数据

# %%
import pandas as pd
import time
i = 0
for date in date_list:
    try:
        pro = ts.pro_api()
        time.sleep(0.75)
        df = pro.fund_daily(ts_code = '510050.SH',trade_date = date,asset='FD')
        if i == 0:
            data = df
            i+=1
        else:
            i+=1
            data = pd.concat([data,df])
        if i%100 == 0:
            print('爬取第{}天数据，数据总长度为:{}'.format(date,len(data)))
    except Exception as err:
        print(err)
        date_list.insert(0,date)
        time.sleep(30)
# Out:
# 爬取第20201206天数据，数据总长度为:7
# 爬取第20201126天数据，数据总长度为:14
# 爬取第20201116天数据，数据总长度为:22
# 爬取第20201106天数据，数据总长度为:28
# 爬取第20201027天数据，数据总长度为:36
# 爬取第20201017天数据，数据总长度为:42
# 爬取第20201007天数据，数据总长度为:48
# 爬取第20200927天数据，数据总长度为:51
# 爬取第20200917天数据，数据总长度为:58
# 爬取第20200907天数据，数据总长度为:66
# 爬取第20200828天数据，数据总长度为:72
# 爬取第20200818天数据，数据总长度为:80
# 爬取第20200808天数据，数据总长度为:86
# 爬取第20200729天数据，数据总长度为:94
# 爬取第20200719天数据，数据总长度为:101
# 爬取第20200709天数据，数据总长度为:108
# 爬取第20200629天数据，数据总长度为:116
# 爬取第20200619天数据，数据总长度为:120
# 爬取第20200609天数据，数据总长度为:128
# 爬取第20200530天数据，数据总长度为:134
# 爬取第20200520天数据，数据总长度为:142
# 爬取第20200510天数据，数据总长度为:149
# 爬取第20200430天数据，数据总长度为:153
# 爬取第20200420天数据，数据总长度为:161
# 爬取第20200410天数据，数据总长度为:167
# 爬取第20200331天数据，数据总长度为:174
# 爬取第20200321天数据，数据总长度为:180
# 爬取第20200311天数据，数据总长度为:188
# 爬取第20200301天数据，数据总长度为:195
# 爬取第20200220天数据，数据总长度为:202
# 爬取第20200210天数据，数据总长度为:210
# 爬取第20200131天数据，数据总长度为:215
# 爬取第20200121天数据，数据总长度为:218
# 爬取第20200111天数据，数据总长度为:224
# 爬取第20200101天数据，数据总长度为:231
# 爬取第20191222天数据，数据总长度为:238
# 爬取第20191212天数据，数据总长度为:245
# 爬取第20191202天数据，数据总长度为:253
# 爬取第20191122天数据，数据总长度为:259
# 爬取第20191112天数据，数据总长度为:267
# 爬取第20191102天数据，数据总长度为:273
# 爬取第20191023天数据，数据总长度为:281
# 爬取第20191013天数据，数据总长度为:288
# 爬取第20191003天数据，数据总长度为:292
# 爬取第20190923天数据，数据总长度为:298
# 爬取第20190913天数据，数据总长度为:303
# 爬取第20190903天数据，数据总长度为:311
# 爬取第20190824天数据，数据总长度为:317
# 爬取第20190814天数据，数据总长度为:325
# 爬取第20190804天数据，数据总长度为:332
# 爬取第20190725天数据，数据总长度为:339
# 爬取第20190715天数据，数据总长度为:347
# 爬取第20190705天数据，数据总长度为:353
# 爬取第20190625天数据，数据总长度为:361
# 爬取第20190615天数据，数据总长度为:367
# 爬取第20190605天数据，数据总长度为:374
# 爬取第20190526天数据，数据总长度为:381
# 爬取第20190516天数据，数据总长度为:388
# 爬取第20190506天数据，数据总长度为:396
# 爬取第20190426天数据，数据总长度为:399
# 爬取第20190416天数据，数据总长度为:407
# 爬取第20190406天数据，数据总长度为:413
# 爬取第20190327天数据，数据总长度为:420
# 爬取第20190317天数据，数据总长度为:427
# 爬取第20190307天数据，数据总长度为:434
# 爬取第20190225天数据，数据总长度为:442
# 爬取第20190215天数据，数据总长度为:448
# 爬取第20190205天数据，数据总长度为:452
# 爬取第20190126天数据，数据总长度为:457
# 爬取第20190116天数据，数据总长度为:465
# 爬取第20190106天数据，数据总长度为:472
# 爬取第20181227天数据，数据总长度为:477
# 爬取第20181217天数据，数据总长度为:485
# 爬取第20181207天数据，数据总长度为:491
# 爬取第20181127天数据，数据总长度为:499
# 爬取第20181117天数据，数据总长度为:505
# 爬取第20181107天数据，数据总长度为:513
# 爬取第20181028天数据，数据总长度为:520
# 爬取第20181018天数据，数据总长度为:527
# 爬取第20181008天数据，数据总长度为:535
# 爬取第20180928天数据，数据总长度为:536
# 爬取第20180918天数据，数据总长度为:543
# 爬取第20180908天数据，数据总长度为:549
# 爬取第20180829天数据，数据总长度为:557
# 爬取第20180819天数据，数据总长度为:564
# 爬取第20180809天数据，数据总长度为:571
# 爬取第20180730天数据，数据总长度为:579
# 爬取第20180720天数据，数据总长度为:585
# 爬取第20180710天数据，数据总长度为:593
# 爬取第20180630天数据，数据总长度为:599
# 爬取第20180620天数据，数据总长度为:607
# 爬取第20180610天数据，数据总长度为:613
# 爬取第20180531天数据，数据总长度为:620
# 爬取第20180521天数据，数据总长度为:628
# 爬取第20180511天数据，数据总长度为:634
# 爬取第20180501天数据，数据总长度为:641
# 爬取第20180421天数据，数据总长度为:646
# 爬取第20180411天数据，数据总长度为:654
# 爬取第20180401天数据，数据总长度为:659
# 爬取第20180322天数据，数据总长度为:666
# 爬取第20180312天数据，数据总长度为:674
# 爬取第20180302天数据，数据总长度为:680
# 爬取第20180220天数据，数据总长度为:686
# 爬取第20180210天数据，数据总长度为:689
# 爬取第20180131天数据，数据总长度为:697
# 爬取第20180121天数据，数据总长度为:704
# 爬取第20180111天数据，数据总长度为:711
# 爬取第20180101天数据，数据总长度为:718
# 爬取第20171222天数据，数据总长度为:724
# 爬取第20171212天数据，数据总长度为:732
# 爬取第20171202天数据，数据总长度为:738
# 爬取第20171122天数据，数据总长度为:746
# 爬取第20171112天数据，数据总长度为:753
# 爬取第20171102天数据，数据总长度为:760
# 爬取第20171023天数据，数据总长度为:768
# 爬取第20171013天数据，数据总长度为:774
# 爬取第20171003天数据，数据总长度为:778
# 爬取第20170923天数据，数据总长度为:783
# 爬取第20170913天数据，数据总长度为:791
# 爬取第20170903天数据，数据总长度为:798
# 爬取第20170824天数据，数据总长度为:805
# 爬取第20170814天数据，数据总长度为:813
# 爬取第20170804天数据，数据总长度为:819
# 爬取第20170725天数据，数据总长度为:827
# 爬取第20170715天数据，数据总长度为:833
# 爬取第20170705天数据，数据总长度为:841
# 爬取第20170625天数据，数据总长度为:848
# 爬取第20170615天数据，数据总长度为:855
# 爬取第20170605天数据，数据总长度为:863
# 爬取第20170526天数据，数据总长度为:867
# 爬取第20170516天数据，数据总长度为:875
# 爬取第20170506天数据，数据总长度为:881
# 爬取第20170426天数据，数据总长度为:888
# 爬取第20170416天数据，数据总长度为:895
# 爬取第20170406天数据，数据总长度为:902
# 爬取第20170327天数据，数据总长度为:908
# 爬取第20170317天数据，数据总长度为:914
# 爬取第20170307天数据，数据总长度为:922
# 爬取第20170225天数据，数据总长度为:928
# 爬取第20170215天数据，数据总长度为:936
# 爬取第20170205天数据，数据总长度为:943
# 爬取第20170126天数据，数据总长度为:945
# 爬取第20170116天数据，数据总长度为:953
# 爬取第20170106天数据，数据总长度为:959
# 爬取第20161227天数据，数据总长度为:966
# 爬取第20161217天数据，数据总长度为:972
# 爬取第20161207天数据，数据总长度为:980
# 爬取第20161127天数据，数据总长度为:987
# 爬取第20161117天数据，数据总长度为:994
# 爬取第20161107天数据，数据总长度为:1002
# 爬取第20161028天数据，数据总长度为:1008
# 爬取第20161018天数据，数据总长度为:1016
# 爬取第20161008天数据，数据总长度为:1022
# 爬取第20160928天数据，数据总长度为:1025
# 爬取第20160918天数据，数据总长度为:1032
# 爬取第20160908天数据，数据总长度为:1037
# 爬取第20160829天数据，数据总长度为:1045
# 爬取第20160819天数据，数据总长度为:1051
# 爬取第20160809天数据，数据总长度为:1059
# 爬取第20160730天数据，数据总长度为:1065
# 爬取第20160720天数据，数据总长度为:1073
# 爬取第20160710天数据，数据总长度为:1080
# 爬取第20160630天数据，数据总长度为:1087
# 爬取第20160620天数据，数据总长度为:1095
# 爬取第20160610天数据，数据总长度为:1100
# 爬取第20160531天数据，数据总长度为:1107
# 爬取第20160521天数据，数据总长度为:1113
# 爬取第20160511天数据，数据总长度为:1121
# 爬取第20160501天数据，数据总长度为:1127
# 爬取第20160421天数据，数据总长度为:1134
# 爬取第20160411天数据，数据总长度为:1142
# 爬取第20160401天数据，数据总长度为:1147
# 爬取第20160322天数据，数据总长度为:1155
# 爬取第20160312天数据，数据总长度为:1161
# 爬取第20160302天数据，数据总长度为:1169
# 爬取第20160221天数据，数据总长度为:1176
# 爬取第20160211天数据，数据总长度为:1181
# 爬取第20160201天数据，数据总长度为:1186
# 爬取第20160122天数据，数据总长度为:1192
# 爬取第20160112天数据，数据总长度为:1200
# 爬取第20160102天数据，数据总长度为:1206
# 爬取第20151223天数据，数据总长度为:1213
# 爬取第20151213天数据，数据总长度为:1220
# 爬取第20151203天数据，数据总长度为:1227
# 爬取第20151123天数据，数据总长度为:1235
# 爬取第20151113天数据，数据总长度为:1241
# 爬取第20151103天数据，数据总长度为:1249
# 爬取第20151024天数据，数据总长度为:1255
# 爬取第20151014天数据，数据总长度为:1263
# 爬取第20151004天数据，数据总长度为:1267
# 爬取第20150924天数据，数据总长度为:1272
# 爬取第20150914天数据，数据总长度为:1280
# 爬取第20150904天数据，数据总长度为:1285
# 爬取第20150825天数据，数据总长度为:1292
# 爬取第20150815天数据，数据总长度为:1298
# 爬取第20150805天数据，数据总长度为:1306
# 爬取第20150726天数据，数据总长度为:1313
# 爬取第20150716天数据，数据总长度为:1320
# 爬取第20150706天数据，数据总长度为:1328
# 爬取第20150626天数据，数据总长度为:1334
# 爬取第20150616天数据，数据总长度为:1341
# 爬取第20150606天数据，数据总长度为:1347
# 爬取第20150527天数据，数据总长度为:1355
# 爬取第20150517天数据，数据总长度为:1362
# 爬取第20150507天数据，数据总长度为:1369
# 爬取第20150427天数据，数据总长度为:1376
# 爬取第20150417天数据，数据总长度为:1382
# 爬取第20150407天数据，数据总长度为:1390
# 爬取第20150328天数据，数据总长度为:1395
# 爬取第20150318天数据，数据总长度为:1403
# 爬取第20150308天数据，数据总长度为:1410
# 爬取第20150226天数据，数据总长度为:1417
# 爬取第20150216天数据，数据总长度为:1420
# 爬取第20150206天数据，数据总长度为:1426
# 爬取第20150127天数据，数据总长度为:1434
# 爬取第20150117天数据，数据总长度为:1440
# 爬取第20150107天数据，数据总长度为:1448
# 爬取第20141228天数据，数据总长度为:1453
# 爬取第20141218天数据，数据总长度为:1460
# 爬取第20141208天数据，数据总长度为:1468
# 爬取第20141128天数据，数据总长度为:1474
# 爬取第20141118天数据，数据总长度为:1482
# 爬取第20141108天数据，数据总长度为:1488
# 爬取第20141029天数据，数据总长度为:1496
# 爬取第20141019天数据，数据总长度为:1503
# 爬取第20141009天数据，数据总长度为:1510
# 爬取第20140929天数据，数据总长度为:1513
# 爬取第20140919天数据，数据总长度为:1519
# 爬取第20140909天数据，数据总长度为:1527
# 爬取第20140830天数据，数据总长度为:1532
# 爬取第20140820天数据，数据总长度为:1540
# 爬取第20140810天数据，数据总长度为:1547
# 爬取第20140731天数据，数据总长度为:1554
# 爬取第20140721天数据，数据总长度为:1562
# 爬取第20140711天数据，数据总长度为:1568
# 爬取第20140701天数据，数据总长度为:1576
# 爬取第20140621天数据，数据总长度为:1582
# 爬取第20140611天数据，数据总长度为:1590
# 爬取第20140601天数据，数据总长度为:1596
# 爬取第20140522天数据，数据总长度为:1603
# 爬取第20140512天数据，数据总长度为:1611
# 爬取第20140502天数据，数据总长度为:1616
# 爬取第20140422天数据，数据总长度为:1623
# 爬取第20140412天数据，数据总长度为:1629
# 爬取第20140402天数据，数据总长度为:1636
# 爬取第20140323天数据，数据总长度为:1643
# 爬取第20140313天数据，数据总长度为:1650
# 爬取第20140303天数据，数据总长度为:1658
# 爬取第20140221天数据，数据总长度为:1664
# 爬取第20140211天数据，数据总长度为:1672
# 爬取第20140201天数据，数据总长度为:1674
# 爬取第20140122天数据，数据总长度为:1681
# 爬取第20140112天数据，数据总长度为:1688
# 爬取第20140102天数据，数据总长度为:1695
# 爬取第20131223天数据，数据总长度为:1702
# 爬取第20131213天数据，数据总长度为:1708
# 爬取第20131203天数据，数据总长度为:1716
# 爬取第20131123天数据，数据总长度为:1722
# 爬取第20131113天数据，数据总长度为:1730
# 爬取第20131103天数据，数据总长度为:1737
# 爬取第20131024天数据，数据总长度为:1744
# 爬取第20131014天数据，数据总长度为:1752
# 爬取第20131004天数据，数据总长度为:1756
# 爬取第20130924天数据，数据总长度为:1761
# 爬取第20130914天数据，数据总长度为:1765
# 爬取第20130904天数据，数据总长度为:1773
# 爬取第20130825天数据，数据总长度为:1780
# 爬取第20130815天数据，数据总长度为:1787
# 爬取第20130805天数据，数据总长度为:1795
# 爬取第20130726天数据，数据总长度为:1801
# 爬取第20130716天数据，数据总长度为:1809
# 爬取第20130706天数据，数据总长度为:1815
# 爬取第20130626天数据，数据总长度为:1823
# 爬取第20130616天数据，数据总长度为:1830
# 爬取第20130606天数据，数据总长度为:1834
# 爬取第20130527天数据，数据总长度为:1842
# 爬取第20130517天数据，数据总长度为:1848
# 爬取第20130507天数据，数据总长度为:1856
# 爬取第20130427天数据，数据总长度为:1859
# 爬取第20130417天数据，数据总长度为:1867
# 爬取第20130407天数据，数据总长度为:1874
# 爬取第20130328天数据，数据总长度为:1879
# 爬取第20130318天数据，数据总长度为:1887
# 爬取第20130308天数据，数据总长度为:1893
# 爬取第20130226天数据，数据总长度为:1901
# 爬取第20130216天数据，数据总长度为:1907
# 爬取第20130206天数据，数据总长度为:1910
# 爬取第20130127天数据，数据总长度为:1917
# 爬取第20130117天数据，数据总长度为:1924
# 爬取第20130107天数据，数据总长度为:1932
# 爬取第20121228天数据，数据总长度为:1935
# 爬取第20121218天数据，数据总长度为:1943
# 爬取第20121208天数据，数据总长度为:1949
# 爬取第20121128天数据，数据总长度为:1957
# 爬取第20121118天数据，数据总长度为:1964
# 爬取第20121108天数据，数据总长度为:1971
# 爬取第20121029天数据，数据总长度为:1979
# 爬取第20121019天数据，数据总长度为:1985
# 爬取第20121009天数据，数据总长度为:1993
# 爬取第20120929天数据，数据总长度为:1994
# 爬取第20120919天数据，数据总长度为:2002
# 爬取第20120909天数据，数据总长度为:2009
# 爬取第20120830天数据，数据总长度为:2016
# 爬取第20120820天数据，数据总长度为:2024
# 爬取第20120810天数据，数据总长度为:2030
# 爬取第20120731天数据，数据总长度为:2038
# 爬取第20120721天数据，数据总长度为:2044
# 爬取第20120711天数据，数据总长度为:2052
# 爬取第20120701天数据，数据总长度为:2059
# 爬取第20120621天数据，数据总长度为:2065
# 爬取第20120611天数据，数据总长度为:2073
# 爬取第20120601天数据，数据总长度为:2079
# 爬取第20120522天数据，数据总长度为:2087
# 爬取第20120512天数据，数据总长度为:2093
# 爬取第20120502天数据，数据总长度为:2101
# 爬取第20120422天数据，数据总长度为:2106
# 爬取第20120412天数据，数据总长度为:2113
# 爬取第20120402天数据，数据总长度为:2118
# 爬取第20120323天数据，数据总长度为:2124
# 爬取第20120313天数据，数据总长度为:2132
# 爬取第20120303天数据，数据总长度为:2138
# 爬取第20120222天数据，数据总长度为:2146
# 爬取第20120212天数据，数据总长度为:2153
# 爬取第20120202天数据，数据总长度为:2160
# 爬取第20120123天数据，数据总长度为:2163
# 爬取第20120113天数据，数据总长度为:2169
# 爬取第20120103天数据，数据总长度为:2176
# 爬取第20111224天数据，数据总长度为:2181
# 爬取第20111214天数据，数据总长度为:2189
# 爬取第20111204天数据，数据总长度为:2196
# 爬取第20111124天数据，数据总长度为:2203
# 爬取第20111114天数据，数据总长度为:2211
# 爬取第20111104天数据，数据总长度为:2217
# 爬取第20111025天数据，数据总长度为:2225
# 爬取第20111015天数据，数据总长度为:2231
# 爬取第20111005天数据，数据总长度为:2236
# 爬取第20110925天数据，数据总长度为:2241
# 爬取第20110915天数据，数据总长度为:2248
# 爬取第20110905天数据，数据总长度为:2255
# 爬取第20110826天数据，数据总长度为:2261
# 爬取第20110816天数据，数据总长度为:2269
# 爬取第20110806天数据，数据总长度为:2275
# 爬取第20110727天数据，数据总长度为:2283
# 爬取第20110717天数据，数据总长度为:2290
# 爬取第20110707天数据，数据总长度为:2297
# 爬取第20110627天数据，数据总长度为:2305
# 爬取第20110617天数据，数据总长度为:2311
# 爬取第20110607天数据，数据总长度为:2319
# 爬取第20110528天数据，数据总长度为:2324
# 爬取第20110518天数据，数据总长度为:2332
# 爬取第20110508天数据，数据总长度为:2339
# 爬取第20110428天数据，数据总长度为:2345
# 爬取第20110418天数据，数据总长度为:2353
# 爬取第20110408天数据，数据总长度为:2359
# 爬取第20110329天数据，数据总长度为:2365
# 爬取第20110319天数据，数据总长度为:2371
# 爬取第20110309天数据，数据总长度为:2379
# 爬取第20110227天数据，数据总长度为:2386
# 爬取第20110217天数据，数据总长度为:2393
# 爬取第20110207天数据，数据总长度为:2399
# 爬取第20110128天数据，数据总长度为:2402
# 爬取第20110118天数据，数据总长度为:2410
# 爬取第20110108天数据，数据总长度为:2416
# 爬取第20101229天数据，数据总长度为:2423
# 爬取第20101219天数据，数据总长度为:2430
# 爬取第20101209天数据，数据总长度为:2437
# 爬取第20101129天数据，数据总长度为:2445
# 爬取第20101119天数据，数据总长度为:2451
# 爬取第20101109天数据，数据总长度为:2459
# 爬取第20101030天数据，数据总长度为:2465
# 爬取第20101020天数据，数据总长度为:2473
# 爬取第20101010天数据，数据总长度为:2480
# 爬取第20100930天数据，数据总长度为:2482
# 爬取第20100920天数据，数据总长度为:2487
# 爬取第20100910天数据，数据总长度为:2493
# 爬取第20100831天数据，数据总长度为:2501
# 爬取第20100821天数据，数据总长度为:2507
# 爬取第20100811天数据，数据总长度为:2515
# 爬取第20100801天数据，数据总长度为:2522
# 爬取第20100722天数据，数据总长度为:2529
# 爬取第20100712天数据，数据总长度为:2537
# 爬取第20100702天数据，数据总长度为:2543
# 爬取第20100622天数据，数据总长度为:2551
# 爬取第20100612天数据，数据总长度为:2554
# 爬取第20100602天数据，数据总长度为:2562
# 爬取第20100523天数据，数据总长度为:2569
# 爬取第20100513天数据，数据总长度为:2576
# 爬取第20100503天数据，数据总长度为:2583
# 爬取第20100423天数据，数据总长度为:2589
# 爬取第20100413天数据，数据总长度为:2597
# 爬取第20100403天数据，数据总长度为:2602
# 爬取第20100324天数据，数据总长度为:2610
# 爬取第20100314天数据，数据总长度为:2617
# 爬取第20100304天数据，数据总长度为:2624
# 爬取第20100222天数据，数据总长度为:2632
# 爬取第20100212天数据，数据总长度为:2633
# 爬取第20100202天数据，数据总长度为:2641
# 爬取第20100123天数据，数据总长度为:2647
# 爬取第20100113天数据，数据总长度为:2655
# 爬取第20100103天数据，数据总长度为:2662
# 爬取第20091224天数据，数据总长度为:2668
# 爬取第20091214天数据，数据总长度为:2676
# 爬取第20091204天数据，数据总长度为:2682
# 爬取第20091124天数据，数据总长度为:2690
# 爬取第20091114天数据，数据总长度为:2696
# 爬取第20091104天数据，数据总长度为:2704
# 爬取第20091025天数据，数据总长度为:2711
# 爬取第20091015天数据，数据总长度为:2718
# 爬取第20091005天数据，数据总长度为:2722
# 爬取第20090925天数据，数据总长度为:2726
# 爬取第20090915天数据，数据总长度为:2734
# 爬取第20090905天数据，数据总长度为:2740
# 爬取第20090826天数据，数据总长度为:2748
# 爬取第20090816天数据，数据总长度为:2755
# 爬取第20090806天数据，数据总长度为:2762
# 爬取第20090727天数据，数据总长度为:2770
# 爬取第20090717天数据，数据总长度为:2776
# 爬取第20090707天数据，数据总长度为:2784
# 爬取第20090627天数据，数据总长度为:2790
# 爬取第20090617天数据，数据总长度为:2798
# 爬取第20090607天数据，数据总长度为:2805
# 爬取第20090528天数据，数据总长度为:2810
# 爬取第20090518天数据，数据总长度为:2818
# 爬取第20090508天数据，数据总长度为:2824
# 爬取第20090428天数据，数据总长度为:2831
# 爬取第20090418天数据，数据总长度为:2837
# 爬取第20090408天数据，数据总长度为:2845
# 爬取第20090329天数据，数据总长度为:2851
# 爬取第20090319天数据，数据总长度为:2858
# 爬取第20090309天数据，数据总长度为:2866
# 爬取第20090227天数据，数据总长度为:2872
# 爬取第20090217天数据，数据总长度为:2880
# 爬取第20090207天数据，数据总长度为:2886
# 爬取第20090128天数据，数据总长度为:2891
# 爬取第20090118天数据，数据总长度为:2896
# 爬取第20090108天数据，数据总长度为:2903
# 爬取第20081229天数据，数据总长度为:2909
# 爬取第20081219天数据，数据总长度为:2915
# 爬取第20081209天数据，数据总长度为:2923
# 爬取第20081129天数据，数据总长度为:2929
# 爬取第20081119天数据，数据总长度为:2937
# 爬取第20081109天数据，数据总长度为:2944
# 爬取第20081030天数据，数据总长度为:2951
# 爬取第20081020天数据，数据总长度为:2959
# 爬取第20081010天数据，数据总长度为:2965
# 爬取第20080930天数据，数据总长度为:2969
# 爬取第20080920天数据，数据总长度为:2974
# 爬取第20080910天数据，数据总长度为:2981
# 爬取第20080831天数据，数据总长度为:2988
# 爬取第20080821天数据，数据总长度为:2995
# 爬取第20080811天数据，数据总长度为:3003
# 爬取第20080801天数据，数据总长度为:3009
# 爬取第20080722天数据，数据总长度为:3017
# 爬取第20080712天数据，数据总长度为:3023
# 爬取第20080702天数据，数据总长度为:3031
# 爬取第20080622天数据，数据总长度为:3038
# 爬取第20080612天数据，数据总长度为:3045
# 爬取第20080602天数据，数据总长度为:3052
# 爬取第20080523天数据，数据总长度为:3058
# 爬取第20080513天数据，数据总长度为:3066
# 爬取第20080503天数据，数据总长度为:3072
# 爬取第20080423天数据，数据总长度为:3078
# 爬取第20080413天数据，数据总长度为:3085
# 爬取第20080403天数据，数据总长度为:3091
# 爬取第20080324天数据，数据总长度为:3099
# 爬取第20080314天数据，数据总长度为:3105
# 爬取第20080304天数据，数据总长度为:3113
# 爬取第20080223天数据，数据总长度为:3119
# 爬取第20080213天数据，数据总长度为:3127
# 爬取第20080203天数据，数据总长度为:3129
# 爬取第20080124天数据，数据总长度为:3136
# 爬取第20080114天数据，数据总长度为:3144
# 爬取第20080104天数据，数据总长度为:3150
# 爬取第20071225天数据，数据总长度为:3156
# 爬取第20071215天数据，数据总长度为:3162
# 爬取第20071205天数据，数据总长度为:3170
# 爬取第20071125天数据，数据总长度为:3177
# 爬取第20071115天数据，数据总长度为:3184
# 爬取第20071105天数据，数据总长度为:3192
# 爬取第20071026天数据，数据总长度为:3198
# 爬取第20071016天数据，数据总长度为:3206
# 爬取第20071006天数据，数据总长度为:3212
# 爬取第20070926天数据，数据总长度为:3215
# 爬取第20070916天数据，数据总长度为:3222
# 爬取第20070906天数据，数据总长度为:3229
# 爬取第20070827天数据，数据总长度为:3237
# 爬取第20070817天数据，数据总长度为:3243
# 爬取第20070807天数据，数据总长度为:3251
# 爬取第20070728天数据，数据总长度为:3257
# 爬取第20070718天数据，数据总长度为:3265
# 爬取第20070708天数据，数据总长度为:3272
# 爬取第20070628天数据，数据总长度为:3279
# 爬取第20070618天数据，数据总长度为:3287
# 爬取第20070608天数据，数据总长度为:3293
# 爬取第20070529天数据，数据总长度为:3301
# 爬取第20070519天数据，数据总长度为:3307
# 爬取第20070509天数据，数据总长度为:3315
# 爬取第20070429天数据，数据总长度为:3317
# 爬取第20070419天数据，数据总长度为:3324
# 爬取第20070409天数据，数据总长度为:3332
# 爬取第20070330天数据，数据总长度为:3338
# 爬取第20070320天数据，数据总长度为:3346
# 爬取第20070310天数据，数据总长度为:3352
# 爬取第20070228天数据，数据总长度为:3360
# 爬取第20070218天数据，数据总长度为:3362
# 爬取第20070208天数据，数据总长度为:3369
# 爬取第20070129天数据，数据总长度为:3377
# 爬取第20070119天数据，数据总长度为:3383
# 爬取第20070109天数据，数据总长度为:3391
# 爬取第20061230天数据，数据总长度为:3394
# 爬取第20061220天数据，数据总长度为:3402
# 爬取第20061210天数据，数据总长度为:3409
# 爬取第20061130天数据，数据总长度为:3416
# 爬取第20061120天数据，数据总长度为:3424
# 爬取第20061110天数据，数据总长度为:3430
# 爬取第20061031天数据，数据总长度为:3438
# 爬取第20061021天数据，数据总长度为:3444
# 爬取第20061011天数据，数据总长度为:3452
# 爬取第20061001天数据，数据总长度为:3454
# 爬取第20060921天数据，数据总长度为:3461
# 爬取第20060911天数据，数据总长度为:3469
# 爬取第20060901天数据，数据总长度为:3475
# 爬取第20060822天数据，数据总长度为:3483
# 爬取第20060812天数据，数据总长度为:3489
# 爬取第20060802天数据，数据总长度为:3497
# 爬取第20060723天数据，数据总长度为:3504
# 爬取第20060713天数据，数据总长度为:3511
# 爬取第20060703天数据，数据总长度为:3519
# 爬取第20060623天数据，数据总长度为:3525
# 爬取第20060613天数据，数据总长度为:3533
# 爬取第20060603天数据，数据总长度为:3539
# 爬取第20060524天数据，数据总长度为:3547
# 爬取第20060514天数据，数据总长度为:3554
# 爬取第20060504天数据，数据总长度为:3559
# 爬取第20060424天数据，数据总长度为:3564
# 爬取第20060414天数据，数据总长度为:3570
# 爬取第20060404天数据，数据总长度为:3578
# 爬取第20060325天数据，数据总长度为:3584
# 爬取第20060315天数据，数据总长度为:3592
# 爬取第20060305天数据，数据总长度为:3599
# 爬取第20060223天数据，数据总长度为:3606
# 爬取第20060213天数据，数据总长度为:3614
# 爬取第20060203天数据，数据总长度为:3619
# 爬取第20060124天数据，数据总长度为:3621
# 爬取第20060114天数据，数据总长度为:3627
# 爬取第20060104天数据，数据总长度为:3635
# 爬取第20051225天数据，数据总长度为:3640
# 爬取第20051215天数据，数据总长度为:3647
# 爬取第20051205天数据，数据总长度为:3655
# 爬取第20051125天数据，数据总长度为:3661
# 爬取第20051115天数据，数据总长度为:3669
# 爬取第20051105天数据，数据总长度为:3675
# 爬取第20051026天数据，数据总长度为:3683
# 爬取第20051016天数据，数据总长度为:3690
# 爬取第20051006天数据，数据总长度为:3695
# 爬取第20050926天数据，数据总长度为:3700
# 爬取第20050916天数据，数据总长度为:3706
# 爬取第20050906天数据，数据总长度为:3714
# 爬取第20050827天数据，数据总长度为:3720
# 爬取第20050817天数据，数据总长度为:3728
# 爬取第20050807天数据，数据总长度为:3735
# 爬取第20050728天数据，数据总长度为:3742
# 爬取第20050718天数据，数据总长度为:3750
# 爬取第20050708天数据，数据总长度为:3756
# 爬取第20050628天数据，数据总长度为:3764
# 爬取第20050618天数据，数据总长度为:3770
# 爬取第20050608天数据，数据总长度为:3778
# 爬取第20050529天数据，数据总长度为:3785
# 爬取第20050519天数据，数据总长度为:3792
# 爬取第20050509天数据，数据总长度为:3800
# 爬取第20050429天数据，数据总长度为:3801
# 爬取第20050419天数据，数据总长度为:3809
# 爬取第20050409天数据，数据总长度为:3815
# 爬取第20050330天数据，数据总长度为:3823
# 爬取第20050320天数据，数据总长度为:3830
# 爬取第20050310天数据，数据总长度为:3837
# 爬取第20050228天数据，数据总长度为:3845
# 爬取第20050218天数据，数据总长度为:3848
# 爬取第20050208天数据，数据总长度为:3848
# 爬取第20050129天数据，数据总长度为:3848
# 爬取第20050119天数据，数据总长度为:3848
# 爬取第20050109天数据，数据总长度为:3848
# 爬取第20041230天数据，数据总长度为:3848
# 爬取第20041220天数据，数据总长度为:3848
# 爬取第20041210天数据，数据总长度为:3848
# 爬取第20041130天数据，数据总长度为:3848
# 爬取第20041120天数据，数据总长度为:3848
# 爬取第20041110天数据，数据总长度为:3848
# 爬取第20041031天数据，数据总长度为:3848
# 爬取第20041021天数据，数据总长度为:3848
# 爬取第20041011天数据，数据总长度为:3848
# 爬取第20041001天数据，数据总长度为:3848
# 爬取第20040921天数据，数据总长度为:3848
# 爬取第20040911天数据，数据总长度为:3848
# 爬取第20040901天数据，数据总长度为:3848
# 爬取第20040822天数据，数据总长度为:3848
# 爬取第20040812天数据，数据总长度为:3848
# 爬取第20040802天数据，数据总长度为:3848
# 爬取第20040723天数据，数据总长度为:3848
# 爬取第20040713天数据，数据总长度为:3848
# 爬取第20040703天数据，数据总长度为:3848
# 爬取第20040623天数据，数据总长度为:3848
# 爬取第20040613天数据，数据总长度为:3848
# 爬取第20040603天数据，数据总长度为:3848
# 爬取第20040524天数据，数据总长度为:3848
# 爬取第20040514天数据，数据总长度为:3848
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-dabb3559dce6> in <module>
#       6     try:
#       7         pro = ts.pro_api()
# ----> 8         time.sleep(0.75)
#       9         df = pro.fund_daily(ts_code = '510050.SH',trade_date = date,asset='FD')
#      10         if i == 0:
#
# KeyboardInterrupt:

# %%
data
# Out:
#       ts_code trade_date  pre_close   open   high    low  close  change  \
# 0   510050.SH   20201215      3.461  3.458  3.471  3.437  3.464   0.003
# 0   510050.SH   20201214      3.429  3.435  3.466  3.430  3.461   0.032
# 0   510050.SH   20201211      3.456  3.469  3.478  3.403  3.429  -0.027
# 0   510050.SH   20201210      3.470  3.461  3.477  3.439  3.456  -0.014
# 0   510050.SH   20201209      3.499  3.507  3.520  3.465  3.470  -0.029
# ..        ...        ...        ...    ...    ...    ...    ...     ...
# 0   510050.SH   20050301      0.872  0.870  0.873  0.865  0.867  -0.005
# 0   510050.SH   20050228      0.880  0.878  0.879  0.870  0.872  -0.008
# 0   510050.SH   20050225      0.876  0.877  0.887  0.875  0.880   0.004
# 0   510050.SH   20050224      0.876  0.876  0.876  0.868  0.876   0.000
# 0   510050.SH   20050223      0.887  0.881  0.882  0.866  0.876  -0.011
#
#     pct_chg          vol       amount
# 0    0.0867   3004023.96  1037206.954
# 0    0.9332   3034085.37  1046907.314
# 0   -0.7813   5406706.55  1857613.082
# 0   -0.4035   4583334.10  1586191.032
# 0   -0.8288   5122861.03  1791501.940
# ..      ...          ...          ...
# 0   -0.5734   2080944.56   180573.596
# 0   -0.9091   1879651.93   164467.462
# 0    0.4566   5064606.95   446597.972
# 0    0.0000   4516142.23   394141.216
# 0   -1.2401  12697425.42  1111793.167
#
# [3848 rows x 11 columns]

# %% [markdown]
# ### 给数据增加标签列，1表示涨，0表示跌

# %%
data_sort = data.sort_values(['ts_code','trade_date'],ascending=['False','False'])

# %%
label = data_sort['pre_close']<=data_sort['close']
data_sort['label'] = label
data_sort.head()
# Out:
#      ts_code trade_date  pre_close   open   high    low  close  change  \
# 0  510050.SH   20050223      0.887  0.881  0.882  0.866  0.876  -0.011
# 0  510050.SH   20050224      0.876  0.876  0.876  0.868  0.876   0.000
# 0  510050.SH   20050225      0.876  0.877  0.887  0.875  0.880   0.004
# 0  510050.SH   20050228      0.880  0.878  0.879  0.870  0.872  -0.008
# 0  510050.SH   20050301      0.872  0.870  0.873  0.865  0.867  -0.005
#
#    pct_chg          vol       amount  label
# 0  -1.2401  12697425.42  1111793.167  False
# 0   0.0000   4516142.23   394141.216   True
# 0   0.4566   5064606.95   446597.972   True
# 0  -0.9091   1879651.93   164467.462  False
# 0  -0.5734   2080944.56   180573.596  False

# %%
data_sort.to_csv('20_year_FD.csv',index = False)
